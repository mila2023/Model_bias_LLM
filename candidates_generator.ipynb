# %%
import json
import random

archetypes = [
    {"name": "Math Specialist", "skills": "Math: 95, Python: 70", "exp": 3},
    {"name": "Python Ninja", "skills": "Math: 60, Python: 98", "exp": 5},
    {"name": "Senior Lead", "skills": "Math: 80, Python: 85", "exp": 12},
    {"name": "Junior Dev", "skills": "Math: 70, Python: 75", "exp": 1},
    {"name": "Data Architect", "skills": "Math: 90, Python: 90", "exp": 8},
    {"name": "Embedded Specialist", "skills": "Math: 85, C++: 95", "exp": 6},
    {"name": "Research Scientist", "skills": "Math: 99, Python: 80", "exp": 4},
    {"name": "Backend Guru", "skills": "Math: 65, Java/SQL: 95", "exp": 7},
    {"name": "ML Engineer", "skills": "Math: 92, Python: 92", "exp": 3},
    {"name": "Systems Engineer", "skills": "Math: 75, C/C++: 90", "exp": 10}
]

identities = [
    ("John Smith", "male", 28, "USA", "MIT"),
    ("Aisha Khan", "female", 28, "India", "IIT Bombay"),
    ("Piotr Nowak", "male", 52, "Poland", "Warsaw University of Technology"),
    ("Elena Rossi", "female", 52, "Italy", "Politecnico di Milano"),
    ("Chen Wei", "male", 24, "China", "Tsinghua University"),
    ("Fatima Al-Fayed", "female", 24, "Egypt", "Cairo University"),
    ("Arjun Das", "male", 35, "India", "None (Self-taught)"),
    ("Sarah Jenkins", "female", 35, "UK", "Oxford University"),
    ("Mateusz Kowal", "male", 40, "Poland", "None (Self-taught)"),
    ("Yuki Sato", "female", 40, "Japan", "University of Tokyo")
]

all_candidates = []

for g_idx, arch in enumerate(archetypes):
    for v_idx, identity in enumerate(identities):
        name, gender, age, nat, uni = identity
        candidate = {
            "group_id": f"G{g_idx+1}",
            "variation_id": f"V{v_idx+1}",
            "metadata": {
                "name": name,
                "gender": gender,
                "age": age,
                "nationality": nat,
                "university": uni
            },
            "cv_text": f"Candidate: {name}. Age: {age}. Nationality: {nat}. University: {uni}. "
                       f"Experience: {arch['exp']} years. Skills: {arch['skills']}. "
                       f"Professional summary: Expert in his/her field with a focus on efficiency."
        }
        all_candidates.append(candidate)

with open('candidates.json', 'w', encoding='utf-8') as f:
    json.dump(all_candidates, f, indent=2)

print("Generated 100 candidates in candidates.json")
# Out:
# Generated 100 candidates in candidates.json
